# %% [markdown]
# ## 1. Installation

# %%
# !pip install quantstats --upgrade --no-cache-dir
# Out:
# Collecting quantstats
#   Downloading QuantStats-0.0.64-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.26.4)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (3.8.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.13.1)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.2.50)
# Requirement already satisfied: python-dateutil>=2.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->quantstats) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->quantstats) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.0->quantstats) (1.17.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2024.12.14)
# Downloading QuantStats-0.0.64-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 65.2 MB/s eta 0:00:00
# Installing collected packages: quantstats
# Successfully installed quantstats-0.0.64

# %% [markdown]
# ## 2. QuantStats Risk metrics on Assets return dataframe

# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('META')

# show sharpe ratio
print(qs.stats.sharpe(stock))

# or using extend_pandas() :)
stock.sharpe()
qs.reports.metrics(stock, "SPY")
# Out:
# 0.7497673241950168
#                     Benchmark (SPY)    Strategy
# ------------------  -----------------  ----------
# Start Period        2012-05-21         2012-05-21
# End Period          2025-01-03         2025-01-03
# Risk-Free Rate      0.0%               0.0%
# Time in Market      100.0%             100.0%
#
# Cumulative Return   465.15%            1,683.54%
# CAGR﹪              9.93%              17.06%
#
# Sharpe              0.91               0.77
# Prob. Sharpe Ratio  99.93%             99.71%
# Sortino             1.28               1.15
# Sortino/√2          0.91               0.82
# Omega               1.16               1.16
#
# Max Drawdown        -33.72%            -76.74%
# Longest DD Days     708                863
#
# Gain/Pain Ratio     0.19               0.16
# Gain/Pain (1M)      1.2                0.93
#
# Payoff Ratio        0.91               0.98
# Profit Factor       1.19               1.16
# Common Sense Ratio  1.13               1.16
# CPC Index           0.6                0.6
# Tail Ratio          0.95               1.0
# Outlier Win Ratio   6.66               2.72
# Outlier Loss Ratio  6.5                2.92
#
# MTD                 1.0%               3.27%
# 3M                  4.41%              5.64%
# 6M                  8.52%              18.88%
# YTD                 1.0%               3.27%
# 1Y                  26.85%             75.27%
# 3Y (ann.)           7.4%               16.1%
# 5Y (ann.)           10.09%             16.7%
# 10Y (ann.)          8.88%              15.17%
# All-time (ann.)     9.93%              17.06%
#
# Avg. Drawdown       -1.57%             -5.3%
# Avg. Drawdown Days  16                 32
# Recovery Factor     5.65               5.05
# Ulcer Index         0.06               0.22
# Serenity Index      2.49               1.02
